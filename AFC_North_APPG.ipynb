# %% [markdown]
# <a href="https://colab.research.google.com/github/maijathomas/MIS-2800/blob/main/AFC_North_APPG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
print ("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
#create AFC_North_APPG in temporary Colab local storage
conn = sqlite3.connect('AFC_North_APPG.db')
print ("Opened database successfully")
# Out:
# Opened database successfully

# %% [markdown]
# # Create a STRICT TABLE

# %%
#define a structure for the data table
conn.execute('''
CREATE TABLE AFC_NORTH_APPG(
    team_name TEXT PRIMARY KEY NOT NULL,
    city TEXT,
    average_ppg REAL,
    wins_2025 INTEGER,
    losses_2025 INTEGER)
    STRICT;
''')

# %% [markdown]
# #Team Stats

# %%
conn.execute('''
INSERT INTO AFC_NORTH_APPG (team_name, city, average_ppg, wins_2025, losses_2025)
VALUES ('Steelers', 'Pittsburgh', 23.4, 10, 7),
('Ravens', 'Baltimore', 24.9, 8, 9),
('Bengals', 'Cincinnati', 24.4, 6, 11),
('Browns', 'Cleveland', 16.4, 5, 12);
''')

# %% [markdown]
# #Filtering Teams

# %%
#slicing the data to show only specific teams
query = "SELECT * FROM AFC_NORTH_APPG WHERE average_ppg > 20"
results = conn.execute(query)
for row in results:
  print(row)
# Out:
# ('Steelers', 'Pittsburgh', 23.4, 10, 7)
# ('Ravens', 'Baltimore', 24.9, 8, 9)
# ('Bengals', 'Cincinnati', 24.4, 6, 11)

# %% [markdown]
# #Sorting Data

# %%
#sort numerically for highests to lowest based on wins
query = "SELECT team_name, wins_2025 FROM AFC_North_APPG ORDER BY wins_2025 DESC"
for row in conn.execute(query):
  print(row)
# Out:
# ('Steelers', 10)
# ('Ravens', 8)
# ('Bengals', 6)
# ('Browns', 5)
